# %% [markdown]
# # Scraping Baseball Reference

# %%
# depens
import pandas as pd
import numpy as np

# %%
link_url = 'https://www.baseball-reference.com/leagues/majors/{}-misc.shtml'
years = [1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2021]

# %%
url_list = []

for year in years:
    url = link_url.format(year)
    print(url)
    url_list.append(url)
# Out:
# https://www.baseball-reference.com/leagues/majors/1990-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1991-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1992-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1993-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1994-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1995-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1996-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1997-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1998-misc.shtml
# https://www.baseball-reference.com/leagues/majors/1999-misc.shtml
# https://www.baseball-reference.com/leagues/majors/2000-misc.shtml
# https://www.baseball-reference.com/leagues/majors/2001-misc.shtml
# https://www.baseball-reference.com/leagues/majors/2002-misc.shtml
# https://www.baseball-reference.com/leagues/majors/2003-misc.shtml
# ...

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [                       Tm  Attendance  Attend/G  BatAge  PAge  BPF  PPF  #HOF  \
#  0    Arizona Diamondbacks     1043010     12877    28.9  28.5   99  100     0
#  1          Atlanta Braves     2299647     28746    28.2  29.5  104  103     0
#  2       Baltimore Orioles      793229      9793    26.7  28.1  102  104     0
#  3          Boston Red Sox     1725323     21300    28.0  29.7  107  107     0
#  4            Chicago Cubs     1978934     24431    29.1  29.4  100  100     0
#  5       Chicago White Sox     1596385     19708    28.1  28.3  102  101     0
#  6         Cincinnati Reds     1505024     18581    28.9  28.9  110  111     0
#  7       Cleveland Indians     1114368     13758    26.7  26.3  100  100     0
#  8        Colorado Rockies     1938645     23934    28.1  28.3  112  114     0
#  9          Detroit Tigers     1102621     13613    28.1  27.3   97   99     0
#  10         Houston Astros     2068509     25537    28.9  28.7  101   99     0
# ...

# %%
df[0]
# Out:
#                        Tm  Attendance  Attend/G  BatAge  PAge  BPF  PPF  #HOF  \
# 0    Arizona Diamondbacks     1043010     12877    28.9  28.5   99  100     0
# 1          Atlanta Braves     2299647     28746    28.2  29.5  104  103     0
# 2       Baltimore Orioles      793229      9793    26.7  28.1  102  104     0
# 3          Boston Red Sox     1725323     21300    28.0  29.7  107  107     0
# 4            Chicago Cubs     1978934     24431    29.1  29.4  100  100     0
# 5       Chicago White Sox     1596385     19708    28.1  28.3  102  101     0
# 6         Cincinnati Reds     1505024     18581    28.9  28.9  110  111     0
# 7       Cleveland Indians     1114368     13758    26.7  26.3  100  100     0
# 8        Colorado Rockies     1938645     23934    28.1  28.3  112  114     0
# 9          Detroit Tigers     1102621     13613    28.1  27.3   97   99     0
# 10         Houston Astros     2068509     25537    28.9  28.7  101   99     0
# ...

# %%
url_list
# Out:
# ['https://www.baseball-reference.com/leagues/majors/1990-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1991-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1992-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1993-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1994-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1995-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1996-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1997-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1998-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/1999-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/2000-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/2001-misc.shtml',
#  'https://www.baseball-reference.com/leagues/majors/2002-misc.shtml',
# ...

# %%
Durl = pd.DataFrame(url_list, columns=['Url'])
Durl
# Out:
#                                                   Url
# 0   https://www.baseball-reference.com/leagues/maj...
# 1   https://www.baseball-reference.com/leagues/maj...
# 2   https://www.baseball-reference.com/leagues/maj...
# 3   https://www.baseball-reference.com/leagues/maj...
# 4   https://www.baseball-reference.com/leagues/maj...
# 5   https://www.baseball-reference.com/leagues/maj...
# 6   https://www.baseball-reference.com/leagues/maj...
# 7   https://www.baseball-reference.com/leagues/maj...
# 8   https://www.baseball-reference.com/leagues/maj...
# 9   https://www.baseball-reference.com/leagues/maj...
# 10  https://www.baseball-reference.com/leagues/maj...
# 11  https://www.baseball-reference.com/leagues/maj...
# 12  https://www.baseball-reference.com/leagues/maj...
# 13  https://www.baseball-reference.com/leagues/maj...
# 14  https://www.baseball-reference.com/leagues/maj...
# 15  https://www.baseball-reference.com/leagues/maj...
# ...

# %%
Durl.columns
# Out:
# Index(['Url'], dtype='object')

# %%
for index, row in Durl.iterrows():
    url = row['Url']
    df = pd.read_html(url, header=0)
    df[0].to_csv(f'./scrape_collect/{index}.csv', encoding='utf-8', index=False)
